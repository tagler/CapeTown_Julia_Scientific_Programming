# %% [markdown]
# # Julia Scientific Programming - Fitting a Parabolic Curve

# %% [markdown]
# University of Cape Town (via Coursera)

# %% [markdown]
# ### Methods

# %%
Pkg.add("Plots")
# Out:
# INFO: Nothing to be done

# %%
using Plots; pyplot()
# Out:
# Plots.PyPlotBackend()

# %% [markdown]
# ### Data

# %%
# read data into array 
data_tofit = readdlm("Week3_PR_Data.dat")
# Out:
# 15x2 Array{Float64,2}:
#  0.1268     -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %%
# alternative: add data into array directly 
data_tofit = [1.6800483    -1.641695388; 
              0.501309281  -0.977697538; 
              1.528012113   0.52771122;
              1.70012253    1.711524991; 
              1.992493625   1.891000015;
              2.706075824  -0.463427794;
              2.994931927  -0.443566619;
              3.491852811  -1.275179133;
              3.501191722  -0.690499597;
              4.459924502  -5.516130799;
              4.936965851  -6.001703074;
              5.023289852  -8.36416901;
              5.04233698   -7.924477517;
              5.50739285  -10.77482371;
              5.568665171 -10.9171878]
# Out:
# 15x2 Array{Float64,2}:
#  1.68005    -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %%
# manually loop through and print values in data_tofit
for values in data_tofit
    println(values) 
end
# Out:
# 1.6800483
# 0.501309281
# 1.528012113
# 1.70012253
# 1.992493625
# 2.706075824
# 2.994931927
# 3.491852811
# 3.501191722
# 4.459924502
# 4.936965851
# 5.023289852
# 5.04233698
# 5.50739285
# 5.568665171
# -1.641695388
# -0.977697538
# 0.52771122
# 1.711524991
# 1.891000015
# -0.463427794
# -0.443566619
# -1.275179133
# -0.690499597
# -5.516130799
# -6.001703074
# -8.36416901
# -7.924477517
# -10.77482371
# -10.9171878

# %%
# manually loop through and print values in data_tofit in a 15x2 matrix
for rs in 1:(size(data_tofit)[1])
    for cs in 1:(size(data_tofit)[2])
        value = data_tofit[rs,cs]
        if cs == 1
            print("$value \t")
        else
            print("$value \n")
        end
    end
end
# Out:
# 1.6800483 	-1.641695388
# 0.501309281 	-0.977697538
# 1.528012113 	0.52771122
# 1.70012253 	1.711524991
# 1.992493625 	1.891000015
# 2.706075824 	-0.463427794
# 2.994931927 	-0.443566619
# 3.491852811 	-1.275179133
# 3.501191722 	-0.690499597
# 4.459924502 	-5.516130799
# 4.936965851 	-6.001703074
# 5.023289852 	-8.36416901
# 5.04233698 	-7.924477517
# 5.50739285 	-10.77482371
# 5.568665171 	-10.9171878

# %%
# create the arrays x and y, assigning x the first column and y the second column
x = data_tofit[:,1]
y = data_tofit[:,2]

# print values
println("x values: $x \n")
println("y values: $y")
# Out:
# x values: [1.6800483,0.501309281,1.528012113,1.70012253,1.992493625,2.706075824,2.994931927,3.491852811,3.501191722,4.459924502,4.936965851,5.023289852,5.04233698,5.50739285,5.568665171]
#
# y values: [-1.641695388,-0.977697538,0.52771122,1.711524991,1.891000015,-0.463427794,-0.443566619,-1.275179133,-0.690499597,-5.516130799,-6.001703074,-8.36416901,-7.924477517,-10.77482371,-10.9171878]

# %% [markdown]
# ### Scatter Plot

# %%
# plot the x and y data points using a scatter plot of the x and y array variables
plot(x, y, 
    title = "Scatter Plot of X vs. Y", 
    xlabel = "X",
    ylabel = "Y",
    linetype = :scatter, 
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ### Parabolic Curve Funtion

# %%
# create a function called parabfit, with x as the argument, returning a*x^2 + b*x + c
function parabfit(x)
    return a*x^2 + b*x + c
end
# Out:
# parabfit (generic function with 1 method)

# %%
# create variables a, b and c, assigning each the value 1
a = 1; b = 1; c = 1;

# plot function 
plot(parabfit, -5, 5,
    title = "Parabfit Function with a=1, b=1, and c=1", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ### Fit Data to Curve

# %%
# modify variables a, b and c
a = 1; b = 1; c = 1;

# scatter plot data
plot(x, y, linetype = :scatter, legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
    title = "Parabfit Function Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
# modify variables a, b and c
a = -1; b = 1; c = 0;

# scatter plot data
plot(x, y, linetype = :scatter, legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
    title = "Parabfit Function Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
# modify variables a, b and c
a = -1; b = 2; c = 0;

# scatter plot data
plot(x, y, linetype = :scatter, legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
    title = "Parabfit Function Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
# modify variables a, b and c
a = -1; b = 3; c = 0;

# scatter plot data
plot(x, y, linetype = :scatter, legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
    title = "Parabfit Function Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
# modify variables a, b and c
a = -1; b = 3; c = -2;

# scatter plot data
plot(x, y, linetype = :scatter, legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
    title = "Parabfit Function Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %%
# modify variables a, b and c
a = -.75; b = 2.75; c = -1.75;

# scatter plot data
plot(x, y, linetype = :scatter, color="blue", legend = false)

# overlay parabolic curve fit
plot!(parabfit, 0, 6,
title = "Final Parabfit Curve Fit (a=$a, b=$b, and c=$c)", 
    xlabel = "X",
    ylabel = "Y",
    line = (:path, :red, :dash),
    legend = false)
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ### Fit Methodology

# %% [markdown]
# Initially, I started with a,b,c equal to (1,1,1), but recognized the data points appeared to fit an upside down parabola (negative a) and the y-intercept appeared to be near 0 (c near 0). Second, I tried (-1,1,0), but the fit was too low for about two-thirds of the points. Third, I tried to adjust b to (-1,2,0) and (-1,3,0) in order to change the shape of the parabola. Fourth, I changed the y-intercept (c) to -2 to improve the fit vertically. Finally, via trial and error, I slightly adjusted these values up/down to produce the best overall fit. The result was (-0.75, -2.75, -1.75).
